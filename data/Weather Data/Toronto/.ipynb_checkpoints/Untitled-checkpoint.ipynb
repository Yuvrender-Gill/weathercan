# %%
import pandas as pd
import seaborn
import numpy as np # linear algebra
import os
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
# Read the demand data for past 3 years
df1 =  pd.read_csv("Toronto20191.csv", index_col=[0], parse_dates=[0])
df1 = df1.drop(columns=['Date/Time'])
df1.head()

df2 =  pd.read_csv("Toronto20192.csv", index_col=[0], parse_dates=[0])
df2 = df2.drop(columns=['Date/Time'])
df2.head()

df_lst = [df1, df2]
df = pd.concat(df_lst)
df.tail()
# Out:
#                      Year  Month  Day   Time  Temp (°C)  Temp Flag  \
# DateTime
# 2019-02-28 19:00:00  2019      2   28  19:00       -7.1        NaN
# 2019-02-28 20:00:00  2019      2   28  20:00       -6.6        NaN
# 2019-02-28 21:00:00  2019      2   28  21:00       -6.7        NaN
# 2019-02-28 22:00:00  2019      2   28  22:00       -6.2        NaN
# 2019-02-28 23:00:00  2019      2   28  23:00       -6.2        NaN
#
#                      Dew Point Temp (°C)  Dew Point Temp Flag  Rel Hum (%)  \
# DateTime
# 2019-02-28 19:00:00                -12.0                  NaN           68
# 2019-02-28 20:00:00                -11.4                  NaN           69
# 2019-02-28 21:00:00                -11.3                  NaN           70
# 2019-02-28 22:00:00                -10.9                  NaN           69
# 2019-02-28 23:00:00                -11.2                  NaN           68
#
#                      Rel Hum Flag   ...     Wind Spd Flag Visibility (km)  \
# DateTime                            ...
# 2019-02-28 19:00:00           NaN   ...               NaN             NaN
# 2019-02-28 20:00:00           NaN   ...               NaN             NaN
# 2019-02-28 21:00:00           NaN   ...               NaN             NaN
# 2019-02-28 22:00:00           NaN   ...               NaN             NaN
# 2019-02-28 23:00:00           NaN   ...               NaN             NaN
#
#                      Visibility Flag Stn Press (kPa)  Stn Press Flag  Hmdx  \
# DateTime
# 2019-02-28 19:00:00              NaN          101.11             NaN   NaN
# 2019-02-28 20:00:00              NaN          101.11             NaN   NaN
# 2019-02-28 21:00:00              NaN          101.09             NaN   NaN
# 2019-02-28 22:00:00              NaN          101.05             NaN   NaN
# 2019-02-28 23:00:00              NaN          101.01             NaN   NaN
#
#                      Hmdx Flag  Wind Chill  Wind Chill Flag  Weather
# DateTime
# 2019-02-28 19:00:00        NaN         NaN              NaN      NaN
# 2019-02-28 20:00:00        NaN         NaN              NaN      NaN
# 2019-02-28 21:00:00        NaN         NaN              NaN      NaN
# 2019-02-28 22:00:00        NaN         NaN              NaN      NaN
# 2019-02-28 23:00:00        NaN         NaN              NaN      NaN
#
# [5 rows x 23 columns]

# %%
def stack_weather_data(station_name, start_year, start_month, end_year, end_month):
    df_lst = []
    df_all = pd.DataFrame([])
    for i in range(start_year, end_year + 1):
        for j in range(start_month, 13):
            if (i == end_year) & (j == (end_month+1)):
                 break
            df = pd.read_csv(str(station_name) + str(i) + str(j) + ".csv", index_col=[0], parse_dates=[0])
            df_all = df_all.append(df)
    df_all.to_csv(station_name+'_all' + '.csv')
    return df_all

# %%
all_df = stack_weather_data('Toronto', 2003, 1, 2019, 3)
all_df.head()
# Out:
#                             Date/Time  Year  Month  Day   Time  Temp (°C)  \
# DateTime
# 2003-01-01 00:00:00  2003-01-01 00:00  2003      1    1  00:00        1.4
# 2003-01-01 01:00:00  2003-01-01 01:00  2003      1    1  01:00        1.5
# 2003-01-01 02:00:00  2003-01-01 02:00  2003      1    1  02:00        1.5
# 2003-01-01 03:00:00  2003-01-01 03:00  2003      1    1  03:00        1.0
# 2003-01-01 04:00:00  2003-01-01 04:00  2003      1    1  04:00        0.7
#
#                     Temp Flag  Dew Point Temp (°C) Dew Point Temp Flag  \
# DateTime
# 2003-01-01 00:00:00       NaN                 -3.9                 NaN
# 2003-01-01 01:00:00       NaN                 -4.4                 NaN
# 2003-01-01 02:00:00       NaN                 -4.2                 NaN
# 2003-01-01 03:00:00       NaN                 -4.7                 NaN
# 2003-01-01 04:00:00       NaN                 -5.2                 NaN
#
#                      Rel Hum (%)   ...    Wind Spd Flag  Visibility (km)  \
# DateTime                           ...
# 2003-01-01 00:00:00         68.0   ...              NaN              NaN
# 2003-01-01 01:00:00         65.0   ...              NaN              NaN
# 2003-01-01 02:00:00         66.0   ...              NaN              NaN
# 2003-01-01 03:00:00         66.0   ...              NaN              NaN
# 2003-01-01 04:00:00         65.0   ...              NaN              NaN
#
#                     Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx  \
# DateTime
# 2003-01-01 00:00:00               M           100.18            NaN   NaN
# 2003-01-01 01:00:00               M           100.23            NaN   NaN
# 2003-01-01 02:00:00               M           100.32            NaN   NaN
# 2003-01-01 03:00:00               M           100.36            NaN   NaN
# 2003-01-01 04:00:00               M           100.43            NaN   NaN
#
#                     Hmdx Flag  Wind Chill Wind Chill Flag  Weather
# DateTime
# 2003-01-01 00:00:00       NaN         NaN             NaN      NaN
# 2003-01-01 01:00:00       NaN         NaN             NaN      NaN
# 2003-01-01 02:00:00       NaN         NaN             NaN      NaN
# 2003-01-01 03:00:00       NaN         NaN             NaN      NaN
# 2003-01-01 04:00:00       NaN         NaN             NaN      NaN
#
# [5 rows x 24 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2655b4b73b76> in <module>
# ----> 1 stack_weather_data('Waterloo', 2003, 1, 2019, 3).tail()
#
# <ipython-input-8-c7df06be998c> in stack_weather_data(station_name, start_year, start_month, end_year, end_month)
#      10             print(df)
#      11             df_lst.append(df)
# ---> 12     df1 = pd.concat(df_lst)
#      13     return df1
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     257
#     258         if len(objs) == 0:
# --> 259             raise ValueError('No objects to concatenate')
#     260
#     261         if keys is None:
#
# ValueError: No objects to concatenate
