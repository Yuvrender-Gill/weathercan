# %%
import pandas as pd
import seaborn
import numpy as np # linear algebra
import os
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
# Read the demand data for past 3 years
df1 =  pd.read_csv("Toronto20191.csv", index_col=[0], parse_dates=[0])
df1 = df1.drop(columns=['Date/Time'])
df1.head()

df2 =  pd.read_csv("Toronto20192.csv", index_col=[0], parse_dates=[0])
df2 = df2.drop(columns=['Date/Time'])
df2.head()

df_lst = [df1, df2]
df = pd.concat(df_lst)
df.tail()
# Out:
#                      Year  Month  Day   Time  Temp (°C)  Temp Flag  \
# DateTime
# 2019-02-28 19:00:00  2019      2   28  19:00       -7.7        NaN
# 2019-02-28 20:00:00  2019      2   28  20:00       -7.7        NaN
# 2019-02-28 21:00:00  2019      2   28  21:00       -7.4        NaN
# 2019-02-28 22:00:00  2019      2   28  22:00       -7.3        NaN
# 2019-02-28 23:00:00  2019      2   28  23:00       -7.4        NaN
#
#                      Dew Point Temp (°C)  Dew Point Temp Flag  Rel Hum (%)  \
# DateTime
# 2019-02-28 19:00:00                -12.9                  NaN           67
# 2019-02-28 20:00:00                -12.6                  NaN           68
# 2019-02-28 21:00:00                -12.4                  NaN           68
# 2019-02-28 22:00:00                -12.3                  NaN           68
# 2019-02-28 23:00:00                -12.3                  NaN           68
#
#                      Rel Hum Flag      ...        Wind Spd Flag  \
# ...

# %%
def stack_weather_data(station_name, start_year, start_month, end_year, end_month):
    df_lst = []
    df_all = pd.DataFrame([])
    for i in range(start_year, end_year + 1):
        for j in range(start_month, 13):
            if (i == end_year) & (j == (end_month+1)):
                 break
            print('Reading.... ' + station_name + str(i) + str(j) + ".csv" + '\n')
            df = pd.read_csv(str(station_name) + str(i) + str(j) + ".csv", index_col=[0], parse_dates=[0])
            df_all = df_all.append(df['Temp (°C)'])
    df_all.to_csv(station_name+'_all' + '.csv')
    return df_all

# %%
all_df = stack_weather_data('Toronto', 2010, 1, 2019, 3)
print(all_df)
# Out:
# Reading.... Toronto20101.csv
#
# Reading.... Toronto20102.csv
#
# Reading.... Toronto20103.csv
#
# Reading.... Toronto20104.csv
#
# Reading.... Toronto20105.csv
#
# Reading.... Toronto20106.csv
#
# Reading.... Toronto20107.csv
#
# Reading.... Toronto20108.csv
#
# Reading.... Toronto20109.csv
#
# Reading.... Toronto201010.csv
#
# Reading.... Toronto201011.csv
#
# Reading.... Toronto201012.csv
#
# Reading.... Toronto20111.csv
#
# Reading.... Toronto20112.csv
#
# Reading.... Toronto20113.csv
#
# Reading.... Toronto20114.csv
#
# Reading.... Toronto20115.csv
#
# Reading.... Toronto20116.csv
#
# Reading.... Toronto20117.csv
#
# Reading.... Toronto20118.csv
#
# Reading.... Toronto20119.csv
#
# Reading.... Toronto201110.csv
#
# Reading.... Toronto201111.csv
#
# Reading.... Toronto201112.csv
#
# Reading.... Toronto20121.csv
#
# Reading.... Toronto20122.csv
#
# Reading.... Toronto20123.csv
#
# Reading.... Toronto20124.csv
#
# Reading.... Toronto20125.csv
#
# Reading.... Toronto20126.csv
#
# ...

# %%
all_df.tail()
# Out:
#                      -1.1  -1.8  -2.8  -3.8  -6.5  0.2  0.8   1  1.1  1.2  \
# DateTime
# 2018-12-31 19:00:00   NaN   NaN   NaN   NaN   NaN  NaN  NaN NaN  NaN  NaN
# 2018-12-31 20:00:00   NaN   NaN   NaN   NaN   NaN  NaN  NaN NaN  NaN  NaN
# 2018-12-31 21:00:00   NaN   NaN   NaN   NaN   NaN  NaN  NaN NaN  NaN  NaN
# 2018-12-31 22:00:00   NaN   NaN   NaN   NaN   NaN  NaN  NaN NaN  NaN  NaN
# 2018-12-31 23:00:00   NaN   NaN   NaN   NaN   NaN  NaN  NaN NaN  NaN  NaN
#
#                       ...    Visibility (km)  Visibility Flag   Weather  \
# DateTime              ...
# 2018-12-31 19:00:00   ...                9.7              NaN  Rain,Fog
# 2018-12-31 20:00:00   ...                9.7              NaN  Rain,Fog
# 2018-12-31 21:00:00   ...                9.7              NaN  Rain,Fog
# 2018-12-31 22:00:00   ...                6.4              NaN  Rain,Fog
# 2018-12-31 23:00:00   ...                9.7              NaN  Rain,Fog
#
# ...
